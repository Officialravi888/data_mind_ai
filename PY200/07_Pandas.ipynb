# %%
import pandas as pd

lst = [10,23,98,34,65,63,25,79,83,48,57,15]

print(type(lst))

s = pd.Series(lst)

print(type(s))
print(s)
# Out:
# <class 'list'>
# <class 'pandas.Series'>
# 0     10
# 1     23
# 2     98
# 3     34
# 4     65
# 5     63
# 6     25
# 7     79
# 8     83
# 9     48
# 10    57
# 11    15
# dtype: int64

# %%
import pandas as pd

df = pd.read_excel(
    r"D:\Ai_06_month_placement\ai_python\data_mind_ai\PY200\file_new.xlsb",engine="pyxlsb"
)

print(df)
# Out:
#    id    name  age   product category  price  quantity       city   date  \
# 0   1    Ravi   25      Milk    Dairy     50        10      Delhi  46082
# 1   2    Amit   28     Bread   Bakery     30        15      Delhi  46083
# 2   3    Neha   24      Eggs    Dairy     60        20     Mumbai  46084
# 3   4   Priya   27      Rice  Grocery     80        25      Delhi  46085
# 4   5   Rahul   30     Sugar  Grocery     45        18     Mumbai  46086
# 5   6  Anjali   26    Butter    Dairy     55        12  Bangalore  46087
# 6   7   Vikas   29      Cake   Bakery    200         5      Delhi  46088
# 7   8   Pooja   23       Oil  Grocery    120        10  Bangalore  46089
# 8   9   Arjun   31    Cheese    Dairy     90         8     Mumbai  46090
# 9  10   Kiran   22  Biscuits   Bakery     20        30      Delhi  46091
#
#    gender
# 0    Male
# 1    Male
# 2  Female
# 3  Female
# 4    Male
# 5  Female
# 6    Male
# 7  Female
# 8    Male
# 9  Female

# %%
data=[["Ravi","25","Milk","Dairy","50","10","Delhi","2026-03-01","Male"]]
d1=pd.DataFrame(data)
d1
# Out:
#       0   1     2      3   4   5      6           7     8
# 0  Ravi  25  Milk  Dairy  50  10  Delhi  2026-03-01  Male
