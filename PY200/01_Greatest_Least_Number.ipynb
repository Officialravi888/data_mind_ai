# %%
number=[2,5,3,7,9,5,8,3,7,5,30,52,48,26,51]

largest=max(number)
smallest=min(number)
unique_sorted = sorted(set(number), reverse=True)
unique_largest=unique_sorted[1] if len(unique_sorted)> 1 else unique_sorted[0]
print(largest)
print(smallest)
print(unique_sorted)
print(unique_largest)
# Out:
# 52
# 2
# [52, 51, 48, 30, 26, 9, 8, 7, 5, 3, 2]
# 51
